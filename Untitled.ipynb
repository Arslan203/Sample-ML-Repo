# %%
import pandas as pd

# %%
df1 = pd.read_csv('dataset 2.8m.csv')
df1
# Out:
#                    PdId  IncidntNum  Incident Code        Category  \
# 0         3114751606302    31147516           6302   LARCENY/THEFT
# 1         5069701104134    50697011           4134         ASSAULT
# 2         6074729204104    60747292           4104         ASSAULT
# 3         7103536315201    71035363          15201         ASSAULT
# 4        11082415274000   110824152          74000  MISSING PERSON
# ...                 ...         ...            ...             ...
# 2129520  17050730416710   170507304          16710   DRUG/NARCOTIC
# 2129521  17071435504014   170714355           4014         ASSAULT
# 2129522  17053348465010   170533484          65010  OTHER OFFENSES
# 2129523  17102776330130   171027763          30130  OTHER OFFENSES
# 2129524  17088142128160   170881421          28160       VANDALISM
#
#                                           Descript  DayOfWeek        Date  \
# 0                      PETTY THEFT FROM A BUILDING     Sunday  09/28/2003
# 1                                          BATTERY  Wednesday  06/22/2005
# 2                                          ASSAULT   Saturday  07/15/2006
# 3                                         STALKING    Tuesday  09/25/2007
# 4                                    MISSING ADULT   Saturday  09/24/2011
# ...                                            ...        ...         ...
# 2129520      POSSESSION OF NARCOTICS PARAPHERNALIA   Thursday  06/22/2017
# 2129521       AGGRAVATED ASSAULT WITH BODILY FORCE     Friday  09/01/2017
# 2129522                   TRAFFIC VIOLATION ARREST     Friday  06/30/2017
# 2129523                 PEDDLING WITHOUT A LICENSE  Wednesday  12/20/2017
# 2129524  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES     Friday  10/27/2017
#
#           Time PdDistrict      Resolution  ...  \
# 0        10:00   SOUTHERN            NONE  ...
# 1        12:20   NORTHERN            NONE  ...
# 2        00:55    CENTRAL            NONE  ...
# 3        00:01    TARAVAL            NONE  ...
# 4        11:00    TARAVAL         LOCATED  ...
# ...        ...        ...             ...  ...
# 2129520  01:42    CENTRAL   ARREST, CITED  ...
# 2129521  17:00       PARK            NONE  ...
# 2129522  17:50    BAYVIEW  ARREST, BOOKED  ...
# 2129523  15:41   SOUTHERN  ARREST, BOOKED  ...
# 2129524  21:30  INGLESIDE            NONE  ...
#
#         Fix It Zones as of 2017-11-06  2 2  DELETE - HSOC Zones 2 2  \
# 0                                      NaN                      NaN
# 1                                      NaN                      NaN
# 2                                      NaN                      NaN
# 3                                      NaN                      NaN
# 4                                      NaN                      NaN
# ...                                    ...                      ...
# 2129520                                NaN                      NaN
# 2129521                                NaN                      NaN
# 2129522                                NaN                      NaN
# 2129523                                3.0                      1.0
# 2129524                                NaN                      NaN
#
#          Fix It Zones as of 2018-02-07 2 2  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2129520                                NaN
# 2129521                                NaN
# 2129522                               22.0
# 2129523                                3.0
# 2129524                                NaN
#
#         CBD, BID and GBD Boundaries as of 2017 2 2  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2129520                                        NaN
# 2129521                                        NaN
# 2129522                                        NaN
# 2129523                                        7.0
# 2129524                                        NaN
#
#          Areas of Vulnerability, 2016 2 2  \
# 0                                     NaN
# 1                                     2.0
# 2                                     2.0
# 3                                     1.0
# 4                                     NaN
# ...                                   ...
# 2129520                               1.0
# 2129521                               1.0
# 2129522                               1.0
# 2129523                               2.0
# 2129524                               2.0
#
#          Central Market/Tenderloin Boundary 2 2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2129520                                     NaN
# 2129521                                     NaN
# 2129522                                     NaN
# 2129523                                     1.0
# 2129524                                     NaN
#
#          Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 2129520                                                NaN
# 2129521                                                NaN
# 2129522                                                NaN
# 2129523                                                1.0
# 2129524                                                NaN
#
#          HSOC Zones as of 2018-06-05 2 2  OWED Public Spaces 2 2  \
# 0                                    NaN                     NaN
# 1                                    NaN                     NaN
# 2                                    NaN                     NaN
# 3                                    NaN                     NaN
# 4                                    NaN                     NaN
# ...                                  ...                     ...
# 2129520                              NaN                     NaN
# 2129521                              NaN                     NaN
# 2129522                              NaN                     NaN
# 2129523                              1.0                    35.0
# 2129524                              NaN                     NaN
#
#          Neighborhoods 2
# 0                    NaN
# 1                   97.0
# 2                  106.0
# 3                   49.0
# 4                    NaN
# ...                  ...
# 2129520             77.0
# 2129521            112.0
# 2129522             56.0
# 2129523             21.0
# 2129524             66.0
#
# [2129525 rows x 35 columns]

# %%
df1.columns
# Out:
# Index(['PdId', 'IncidntNum', 'Incident Code', 'Category', 'Descript',
#        'DayOfWeek', 'Date', 'Time', 'PdDistrict', 'Resolution', 'Address', 'X',
#        'Y', 'location', 'SF Find Neighborhoods 2 2',
#        'Current Police Districts 2 2', 'Current Supervisor Districts 2 2',
#        'Analysis Neighborhoods 2 2', 'DELETE - Fire Prevention Districts 2 2',
#        'DELETE - Police Districts 2 2', 'DELETE - Supervisor Districts 2 2',
#        'DELETE - Zip Codes 2 2', 'DELETE - Neighborhoods 2 2',
#        'DELETE - 2017 Fix It Zones 2 2',
#        'Civic Center Harm Reduction Project Boundary 2 2',
#        'Fix It Zones as of 2017-11-06  2 2', 'DELETE - HSOC Zones 2 2',
#        'Fix It Zones as of 2018-02-07 2 2',
#        'CBD, BID and GBD Boundaries as of 2017 2 2',
#        'Areas of Vulnerability, 2016 2 2',
#        'Central Market/Tenderloin Boundary 2 2',
#        'Central Market/Tenderloin Boundary Polygon - Updated 2 2',
#        'HSOC Zones as of 2018-06-05 2 2', 'OWED Public Spaces 2 2',
#        'Neighborhoods 2'],
#       dtype='object')

# %%
df = df1.loc[:, df1.columns[3]:df1.columns[10]]

# %%
df
# Out:
#                Category                                   Descript  DayOfWeek  \
# 0         LARCENY/THEFT                PETTY THEFT FROM A BUILDING     Sunday
# 1               ASSAULT                                    BATTERY  Wednesday
# 2               ASSAULT                                    ASSAULT   Saturday
# 3               ASSAULT                                   STALKING    Tuesday
# 4        MISSING PERSON                              MISSING ADULT   Saturday
# ...                 ...                                        ...        ...
# 2129520   DRUG/NARCOTIC      POSSESSION OF NARCOTICS PARAPHERNALIA   Thursday
# 2129521         ASSAULT       AGGRAVATED ASSAULT WITH BODILY FORCE     Friday
# 2129522  OTHER OFFENSES                   TRAFFIC VIOLATION ARREST     Friday
# 2129523  OTHER OFFENSES                 PEDDLING WITHOUT A LICENSE  Wednesday
# 2129524       VANDALISM  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES     Friday
#
#                Date   Time PdDistrict      Resolution  \
# 0        09/28/2003  10:00   SOUTHERN            NONE
# 1        06/22/2005  12:20   NORTHERN            NONE
# 2        07/15/2006  00:55    CENTRAL            NONE
# 3        09/25/2007  00:01    TARAVAL            NONE
# 4        09/24/2011  11:00    TARAVAL         LOCATED
# ...             ...    ...        ...             ...
# 2129520  06/22/2017  01:42    CENTRAL   ARREST, CITED
# 2129521  09/01/2017  17:00       PARK            NONE
# 2129522  06/30/2017  17:50    BAYVIEW  ARREST, BOOKED
# 2129523  12/20/2017  15:41   SOUTHERN  ARREST, BOOKED
# 2129524  10/27/2017  21:30  INGLESIDE            NONE
#
#                                Address
# 0                  1ST ST / BRANNAN ST
# 1                1200 Block of EDDY ST
# 2              1600 Block of POWELL ST
# 3                400 Block of ULLOA ST
# 4            3200 Block of SAN JOSE AV
# ...                                ...
# 2129520         BROADWAY ST / DAVIS ST
# 2129521  HAIGHT ST / BUENAVISTAWEST AV
# 2129522          ILLINOIS ST / 23RD ST
# 2129523             7TH ST / MARKET ST
# 2129524         100 Block of MONETA WY
#
# [2129525 rows x 8 columns]

# %%
for i in range(df.shape[0]):
    a, b, c = df.at[i, 'Date'].split('/')
    df.at[i, 'Date'] = b + '.' + a + '.' + c

# %%
df
# Out:
#                Category                                   Descript  DayOfWeek  \
# 0         LARCENY/THEFT                PETTY THEFT FROM A BUILDING     Sunday
# 1               ASSAULT                                    BATTERY  Wednesday
# 2               ASSAULT                                    ASSAULT   Saturday
# 3               ASSAULT                                   STALKING    Tuesday
# 4        MISSING PERSON                              MISSING ADULT   Saturday
# ...                 ...                                        ...        ...
# 2129520   DRUG/NARCOTIC      POSSESSION OF NARCOTICS PARAPHERNALIA   Thursday
# 2129521         ASSAULT       AGGRAVATED ASSAULT WITH BODILY FORCE     Friday
# 2129522  OTHER OFFENSES                   TRAFFIC VIOLATION ARREST     Friday
# 2129523  OTHER OFFENSES                 PEDDLING WITHOUT A LICENSE  Wednesday
# 2129524       VANDALISM  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES     Friday
#
#                Date   Time PdDistrict      Resolution  \
# 0        28.09.2003  10:00   SOUTHERN            NONE
# 1        22.06.2005  12:20   NORTHERN            NONE
# 2        15.07.2006  00:55    CENTRAL            NONE
# 3        25.09.2007  00:01    TARAVAL            NONE
# 4        24.09.2011  11:00    TARAVAL         LOCATED
# ...             ...    ...        ...             ...
# 2129520  22.06.2017  01:42    CENTRAL   ARREST, CITED
# 2129521  01.09.2017  17:00       PARK            NONE
# 2129522  30.06.2017  17:50    BAYVIEW  ARREST, BOOKED
# 2129523  20.12.2017  15:41   SOUTHERN  ARREST, BOOKED
# 2129524  27.10.2017  21:30  INGLESIDE            NONE
#
#                                Address
# 0                  1ST ST / BRANNAN ST
# 1                1200 Block of EDDY ST
# 2              1600 Block of POWELL ST
# 3                400 Block of ULLOA ST
# 4            3200 Block of SAN JOSE AV
# ...                                ...
# 2129520         BROADWAY ST / DAVIS ST
# 2129521  HAIGHT ST / BUENAVISTAWEST AV
# 2129522          ILLINOIS ST / 23RD ST
# 2129523             7TH ST / MARKET ST
# 2129524         100 Block of MONETA WY
#
# [2129525 rows x 8 columns]

# %%
df['title'] = df['Category']+ ' on ' + df['Date']

# %%
df['body'] = df['Descript'] + ' at ' + df['DayOfWeek'] + ' ' + df['Time'] + ' in ' + df['PdDistrict'] + ' ' + df['Address'] + '.Resolution: ' + df['Resolution']

# %%
df
# Out:
#                Category                                   Descript  DayOfWeek  \
# 0         LARCENY/THEFT                PETTY THEFT FROM A BUILDING     Sunday
# 1               ASSAULT                                    BATTERY  Wednesday
# 2               ASSAULT                                    ASSAULT   Saturday
# 3               ASSAULT                                   STALKING    Tuesday
# 4        MISSING PERSON                              MISSING ADULT   Saturday
# ...                 ...                                        ...        ...
# 2129520   DRUG/NARCOTIC      POSSESSION OF NARCOTICS PARAPHERNALIA   Thursday
# 2129521         ASSAULT       AGGRAVATED ASSAULT WITH BODILY FORCE     Friday
# 2129522  OTHER OFFENSES                   TRAFFIC VIOLATION ARREST     Friday
# 2129523  OTHER OFFENSES                 PEDDLING WITHOUT A LICENSE  Wednesday
# 2129524       VANDALISM  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES     Friday
#
#                Date   Time PdDistrict      Resolution  \
# 0        28.09.2003  10:00   SOUTHERN            NONE
# 1        22.06.2005  12:20   NORTHERN            NONE
# 2        15.07.2006  00:55    CENTRAL            NONE
# 3        25.09.2007  00:01    TARAVAL            NONE
# 4        24.09.2011  11:00    TARAVAL         LOCATED
# ...             ...    ...        ...             ...
# 2129520  22.06.2017  01:42    CENTRAL   ARREST, CITED
# 2129521  01.09.2017  17:00       PARK            NONE
# 2129522  30.06.2017  17:50    BAYVIEW  ARREST, BOOKED
# 2129523  20.12.2017  15:41   SOUTHERN  ARREST, BOOKED
# 2129524  27.10.2017  21:30  INGLESIDE            NONE
#
#                                Address                         title  \
# 0                  1ST ST / BRANNAN ST   LARCENY/THEFT on 28.09.2003
# 1                1200 Block of EDDY ST         ASSAULT on 22.06.2005
# 2              1600 Block of POWELL ST         ASSAULT on 15.07.2006
# 3                400 Block of ULLOA ST         ASSAULT on 25.09.2007
# 4            3200 Block of SAN JOSE AV  MISSING PERSON on 24.09.2011
# ...                                ...                           ...
# 2129520         BROADWAY ST / DAVIS ST   DRUG/NARCOTIC on 22.06.2017
# 2129521  HAIGHT ST / BUENAVISTAWEST AV         ASSAULT on 01.09.2017
# 2129522          ILLINOIS ST / 23RD ST  OTHER OFFENSES on 30.06.2017
# 2129523             7TH ST / MARKET ST  OTHER OFFENSES on 20.12.2017
# 2129524         100 Block of MONETA WY       VANDALISM on 27.10.2017
#
#                                                       body
# 0        PETTY THEFT FROM A BUILDING at Sunday 10:00 in...
# 1        BATTERY at Wednesday 12:20 in NORTHERN 1200 Bl...
# 2        ASSAULT at Saturday 00:55 in CENTRAL 1600 Bloc...
# 3        STALKING at Tuesday 00:01 in TARAVAL 400 Block...
# 4        MISSING ADULT at Saturday 11:00 in TARAVAL 320...
# ...                                                    ...
# 2129520  POSSESSION OF NARCOTICS PARAPHERNALIA at Thurs...
# 2129521  AGGRAVATED ASSAULT WITH BODILY FORCE at Friday...
# 2129522  TRAFFIC VIOLATION ARREST at Friday 17:50 in BA...
# 2129523  PEDDLING WITHOUT A LICENSE at Wednesday 15:41 ...
# 2129524  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES at F...
#
# [2129525 rows x 10 columns]

# %%
df2 = df.drop(['Category', 'Descript', 'DayOfWeek', 'Date', 'Time', 'PdDistrict', 'Resolution', 'Address'], axis=1)

# %%
df2
# Out:
#                                 title  \
# 0         LARCENY/THEFT on 28.09.2003
# 1               ASSAULT on 22.06.2005
# 2               ASSAULT on 15.07.2006
# 3               ASSAULT on 25.09.2007
# 4        MISSING PERSON on 24.09.2011
# ...                               ...
# 2129520   DRUG/NARCOTIC on 22.06.2017
# 2129521         ASSAULT on 01.09.2017
# 2129522  OTHER OFFENSES on 30.06.2017
# 2129523  OTHER OFFENSES on 20.12.2017
# 2129524       VANDALISM on 27.10.2017
#
#                                                       body
# 0        PETTY THEFT FROM A BUILDING at Sunday 10:00 in...
# 1        BATTERY at Wednesday 12:20 in NORTHERN 1200 Bl...
# 2        ASSAULT at Saturday 00:55 in CENTRAL 1600 Bloc...
# 3        STALKING at Tuesday 00:01 in TARAVAL 400 Block...
# 4        MISSING ADULT at Saturday 11:00 in TARAVAL 320...
# ...                                                    ...
# 2129520  POSSESSION OF NARCOTICS PARAPHERNALIA at Thurs...
# 2129521  AGGRAVATED ASSAULT WITH BODILY FORCE at Friday...
# 2129522  TRAFFIC VIOLATION ARREST at Friday 17:50 in BA...
# 2129523  PEDDLING WITHOUT A LICENSE at Wednesday 15:41 ...
# 2129524  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES at F...
#
# [2129525 rows x 2 columns]

# %%
class Document:
    def __init__(self, title, text, t_v):
        # можете здесь какие-нибудь свои поля подобавлять
        self.title = title
        self.text = text
        self.title_vec = t_v
    
    def format(self, query):
        # возвращает пару тайтл-текст, отформатированную под запрос
        return [self.title, self.text + ' ...']

# %%
import io
import numpy as np

from tqdm import tqdm
from itertools import islice


def load_vectors(fname, limit):
    fin = io.open(fname, 'r', encoding = 'utf-8', newline = '\n', errors = 'ignore')
    n, d = map(int, fin.readline().split())
    data = {}
    for line in tqdm(islice(fin, limit), total = limit):
        tokens = line.rstrip().split(' ')
        data[tokens[0]] = np.array(list(map(float, tokens[1:])))
    return data

# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip -O crawl-300d-2M.vec.zip
# !unzip crawl-300d-2M.vec.zip
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# unzip:  cannot find either crawl-300d-2M.vec.zip or crawl-300d-2M.vec.zip.zip.
